# %%
import serial
import pandas as pd
import time
ser = serial.Serial('com3', 9600)
counter = 0
f = open('log4.txt', 'w')
while True:
    try:
        data = ser.readline()
    except:
        break
    data = data.decode()
    print(data)
    f.write(data)
    f.write(str(time.localtime(time.time()).tm_sec)+ '\n')
f.close()
# Out:
# Testing device connections...
#
# MPU6050 connection successful
#
# system is ready!
#
# Print a to start
#
#
#
# Send any character to begin demo:
#
# Initializing DMP...
#
# >.....*.>......
#
#
#
# //		X Accel		Y Accel		Z Accel		X Gyro		Y Gyro		Z Gyro
#
# // OFFSETS	-4026.00000,	-541.00000,	1412.00000,	113.00000,	24.00000,	22.00000
#
#
#
# Enabling DMP...
#
# Enabling interrupt detection (Arduino external interrupt 0)...
#
# DMP ready! Waiting for first interrupt...
#
# -28aaa-395aa-188aa0
#
# 25aaaa131aaa9aaaaa0
#
# 9aaaaa114aaa18aaaa0
#
# -1aaaa88aaaa21aaaa0
#
# -7aaaa59aaaa7aaaaa0
#
# -11aaa33aaaa-5aaaa0
#
# -22aaa12aaaa-9aaaa0
#
# -23aaa-60aaa-17aaa0
#
# -17aaa-138aa-30aaa0
#
# -44aaa-223aa-29aaa0
#
# -64aaa-268aa-31aaa0
#
# -50aaa-292aa-32aaa0
#
# -56aaa-308aa-30aaa0
#
# -79aaa-342aa-34aaa0
#
# -63aaa-336aa-36aaa0
#
# -21aaa-315aa-32aaa0
#
# 43aaaa-264aa-36aaa0
#
# 83aaaa-228aa-38aaa0
#
# 128aaa-237aa-23aaa0
#
# 143aaa-226aa-32aaa0
#
# 144aaa-203aa-29aaa0
#
# ...
